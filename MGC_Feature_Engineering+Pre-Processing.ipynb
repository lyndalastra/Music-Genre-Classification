# %%
import pandas as pd
import json
import math
import os
import librosa

# %% [markdown]
# ## Feature Engineering

# %%
DATASET_PATH = "genres"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION


def save_new_features(dataset_path, json_path, n_fft=2048, hop_length=512, num_segments=1):
    """Extracts features from music dataset and saves them into a json file along witgh genre labels.
        :param dataset_path (str): Path to dataset
        :param json_path (str): Path to json file used to save features
        :param n_fft (int): Interval we consider to apply FFT. Measured in # of samples
        :param hop_length (int): Sliding window for FFT. Measured in # of samples
        :param: num_segments (int): Number of segments we want to divide sample tracks into
        """

    # dictionary to store filename, label, and sound features
    data = {
        "filename" : [],
        "label": [],
        "chroma_stft1": [],
        "chroma_stft2": [],
        "chroma_stft3": [],
        "chroma_stft4": [],
        "chroma_stft5": [],
        "chroma_stft6": [],
        "chroma_stft7": [],
        "chroma_stft8": [],
        "chroma_stft9": [],
        "chroma_stft10": [],
        "chroma_stft11": [],
        "chroma_stft12": [],
        "chroma_cqt1": [],
        "chroma_cqt2": [],
        "chroma_cqt3": [],
        "chroma_cqt4": [],
        "chroma_cqt5": [],
        "chroma_cqt6": [],
        "chroma_cqt7": [],
        "chroma_cqt8": [],
        "chroma_cqt9": [],
        "chroma_cqt10": [],
        "chroma_cqt11": [],
        "chroma_cqt12": [],
        "chroma_cens1": [],
        "chroma_cens2": [],
        "chroma_cens3": [],
        "chroma_cens4": [],
        "chroma_cens5": [],
        "chroma_cens6": [],
        "chroma_cens7": [],
        "chroma_cens8": [],
        "chroma_cens9": [],
        "chroma_cens10": [],
        "chroma_cens11": [],
        "chroma_cens12": [],
        "rms": [],
        "spectral_centroid": [], 
        "spectral_bandwidth": [], 
        "spectral_flatness": [],
        "spectral_rolloff": [],
        "spectral_contrast1": [],
        "spectral_contrast2": [],
        "spectral_contrast3": [],
        "spectral_contrast4": [],
        "spectral_contrast5": [],
        "spectral_contrast6": [],
        "spectral_contrast7": [],
        "poly_features1": [],
        "poly_features2": [],
        "tonnetz1": [],
        "tonnetz2": [],
        "tonnetz3": [],
        "tonnetz4": [],
        "tonnetz5": [],
        "tonnetz6": [],
        "zero_crossing_rate": [],
        "mfcc1": [],
        "mfcc2": [],
        "mfcc3": [],
        "mfcc4": [],
        "mfcc5": [],
        "mfcc6": [],
        "mfcc7": [],
        "mfcc8": [],
        "mfcc9": [],
        "mfcc10": [],
        "mfcc11": [],
        "mfcc12": [],
        "mfcc13": [],
        "mfcc14": [],
        "mfcc15": [],
        "mfcc16": [],
        "mfcc17": [],
        "mfcc18": [],
        "mfcc19": [],
        "mfcc20": [],
        "mfcc21": [],
        "mfcc22": [],
        "mfcc23": [],
        "mfcc24": [],
        "mfcc25": [],
        "mfcc26": [],
        "mfcc27": [],
        "mfcc28": [],
        "mfcc29": [],
        "mfcc30": [],
        "mfcc31": [],
        "mfcc32": [],
        "mfcc33": [],
        "mfcc34": [],
        "mfcc35": [],
        "mfcc36": [],
        "mfcc37": [],
        "mfcc38": [],
        "mfcc39": [],
        "mfcc40": [],
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # shows genre label (i.e., sub-folder name) when collecting data
            semantic_label = dirpath.split("/")[-1]
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

            # load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract spectral features
                    chroma_stft1 = librosa.feature.chroma_stft(signal[start:finish])[0].mean()
                    chroma_stft1 = chroma_stft1.T
                    chroma_stft2 = librosa.feature.chroma_stft(signal[start:finish])[1].mean()
                    chroma_stft2 = chroma_stft2.T
                    chroma_stft3 = librosa.feature.chroma_stft(signal[start:finish])[2].mean()
                    chroma_stft3 = chroma_stft3.T
                    chroma_stft4 = librosa.feature.chroma_stft(signal[start:finish])[3].mean()
                    chroma_stft4 = chroma_stft4.T
                    chroma_stft5 = librosa.feature.chroma_stft(signal[start:finish])[4].mean()
                    chroma_stft5 = chroma_stft5.T
                    chroma_stft6 = librosa.feature.chroma_stft(signal[start:finish])[5].mean()
                    chroma_stft6 = chroma_stft6.T
                    chroma_stft7 = librosa.feature.chroma_stft(signal[start:finish])[6].mean()
                    chroma_stft7 = chroma_stft7.T
                    chroma_stft8 = librosa.feature.chroma_stft(signal[start:finish])[7].mean()
                    chroma_stft8 = chroma_stft8.T
                    chroma_stft9 = librosa.feature.chroma_stft(signal[start:finish])[8].mean()
                    chroma_stft9 = chroma_stft9.T
                    chroma_stft10 = librosa.feature.chroma_stft(signal[start:finish])[9].mean()
                    chroma_stft10 = chroma_stft10.T
                    chroma_stft11 = librosa.feature.chroma_stft(signal[start:finish])[10].mean()
                    chroma_stft11 = chroma_stft11.T
                    chroma_stft12 = librosa.feature.chroma_stft(signal[start:finish])[11].mean()
                    chroma_stft12 = chroma_stft12.T
                    
                    chroma_cqt1 = librosa.feature.chroma_cqt(signal[start:finish])[0].mean()
                    chroma_cqt1 = chroma_cqt1.T
                    chroma_cqt2 = librosa.feature.chroma_cqt(signal[start:finish])[1].mean()
                    chroma_cqt2 = chroma_cqt2.T
                    chroma_cqt3 = librosa.feature.chroma_cqt(signal[start:finish])[2].mean()
                    chroma_cqt3 = chroma_cqt3.T
                    chroma_cqt4 = librosa.feature.chroma_cqt(signal[start:finish])[3].mean()
                    chroma_cqt4 = chroma_cqt4.T
                    chroma_cqt5 = librosa.feature.chroma_cqt(signal[start:finish])[4].mean()
                    chroma_cqt5 = chroma_cqt5.T
                    chroma_cqt6 = librosa.feature.chroma_cqt(signal[start:finish])[5].mean()
                    chroma_cqt6 = chroma_cqt6.T
                    chroma_cqt7 = librosa.feature.chroma_cqt(signal[start:finish])[6].mean()
                    chroma_cqt7 = chroma_cqt7.T
                    chroma_cqt8 = librosa.feature.chroma_cqt(signal[start:finish])[7].mean()
                    chroma_cqt8 = chroma_cqt8.T
                    chroma_cqt9 = librosa.feature.chroma_cqt(signal[start:finish])[8].mean()
                    chroma_cqt9 = chroma_cqt9.T
                    chroma_cqt10 = librosa.feature.chroma_cqt(signal[start:finish])[9].mean()
                    chroma_cqt10 = chroma_cqt10.T
                    chroma_cqt11 = librosa.feature.chroma_cqt(signal[start:finish])[10].mean()
                    chroma_cqt11 = chroma_cqt11.T
                    chroma_cqt12 = librosa.feature.chroma_cqt(signal[start:finish])[11].mean()
                    chroma_cqt12 = chroma_cqt12.T
                    
                    chroma_cens1 = librosa.feature.chroma_cens(signal[start:finish])[0].mean()
                    chroma_cens1 = chroma_cens1.T
                    chroma_cens2 = librosa.feature.chroma_cens(signal[start:finish])[1].mean()
                    chroma_cens2 = chroma_cens2.T
                    chroma_cens3 = librosa.feature.chroma_cens(signal[start:finish])[2].mean()
                    chroma_cens3 = chroma_cens3.T
                    chroma_cens4 = librosa.feature.chroma_cens(signal[start:finish])[3].mean()
                    chroma_cens4 = chroma_cens4.T
                    chroma_cens5 = librosa.feature.chroma_cens(signal[start:finish])[4].mean()
                    chroma_cens5 = chroma_cens5.T
                    chroma_cens6 = librosa.feature.chroma_cens(signal[start:finish])[5].mean()
                    chroma_cens6 = chroma_cens6.T
                    chroma_cens7 = librosa.feature.chroma_cens(signal[start:finish])[6].mean()
                    chroma_cens7 = chroma_cens7.T
                    chroma_cens8 = librosa.feature.chroma_cens(signal[start:finish])[7].mean()
                    chroma_cens8 = chroma_cens8.T
                    chroma_cens9 = librosa.feature.chroma_cens(signal[start:finish])[8].mean()
                    chroma_cens9 = chroma_cens9.T
                    chroma_cens10 = librosa.feature.chroma_cens(signal[start:finish])[9].mean()
                    chroma_cens10 = chroma_cens10.T
                    chroma_cens11 = librosa.feature.chroma_cens(signal[start:finish])[10].mean()
                    chroma_cens11 = chroma_cens11.T
                    chroma_cens12 = librosa.feature.chroma_cens(signal[start:finish])[11].mean()
                    chroma_cens12 = chroma_cens12.T
                    
                    rms = librosa.feature.rms(signal[start:finish]).mean()
                    rms = rms.T
                    
                    spectral_centroid = librosa.feature.spectral_centroid(signal[start:finish]).mean()
                    spectral_centroid = spectral_centroid.T
                    
                    spectral_bandwidth = librosa.feature.spectral_bandwidth(signal[start:finish]).mean()
                    spectral_bandwidth = spectral_bandwidth.T
                    
                    spectral_flatness = librosa.feature.spectral_flatness(signal[start:finish]).mean()
                    spectral_flatness = spectral_flatness.T
                    
                    spectral_rolloff = librosa.feature.spectral_rolloff(signal[start:finish]).mean()
                    spectral_rolloff = spectral_rolloff.T
                    
                    spectral_contrast1 = librosa.feature.spectral_contrast(signal[start:finish])[0].mean()
                    spectral_contrast1 = spectral_contrast1.T
                    spectral_contrast2 = librosa.feature.spectral_contrast(signal[start:finish])[1].mean()
                    spectral_contrast2 = spectral_contrast2.T
                    spectral_contrast3 = librosa.feature.spectral_contrast(signal[start:finish])[2].mean()
                    spectral_contrast3 = spectral_contrast3.T
                    spectral_contrast4 = librosa.feature.spectral_contrast(signal[start:finish])[3].mean()
                    spectral_contrast4 = spectral_contrast4.T
                    spectral_contrast5 = librosa.feature.spectral_contrast(signal[start:finish])[4].mean()
                    spectral_contrast5 = spectral_contrast5.T
                    spectral_contrast6 = librosa.feature.spectral_contrast(signal[start:finish])[5].mean()
                    spectral_contrast6 = spectral_contrast6.T
                    spectral_contrast7 = librosa.feature.spectral_contrast(signal[start:finish])[6].mean()
                    spectral_contrast7 = spectral_contrast7.T
                    
                    poly_features1 = librosa.feature.poly_features(signal[start:finish])[0].mean()
                    poly_features1 = poly_features1.T
                    poly_features2 = librosa.feature.poly_features(signal[start:finish])[1].mean()
                    poly_features2 = poly_features2.T
                    
                    tonnetz1 = librosa.feature.tonnetz(signal[start:finish])[0].mean()
                    tonnetz1 = tonnetz1.T
                    tonnetz2 = librosa.feature.tonnetz(signal[start:finish])[1].mean()
                    tonnetz2 = tonnetz2.T
                    tonnetz3 = librosa.feature.tonnetz(signal[start:finish])[2].mean()
                    tonnetz3 = tonnetz3.T
                    tonnetz4 = librosa.feature.tonnetz(signal[start:finish])[3].mean()
                    tonnetz4 = tonnetz4.T
                    tonnetz5 = librosa.feature.tonnetz(signal[start:finish])[4].mean()
                    tonnetz5 = tonnetz5.T
                    tonnetz6 = librosa.feature.tonnetz(signal[start:finish])[5].mean()
                    tonnetz6 = tonnetz6.T

                    zero_crossing_rate = librosa.feature.zero_crossing_rate(signal[start:finish]).mean()
                    zero_crossing_rate = zero_crossing_rate.T
                    
                    mfcc1 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[0].mean()
                    mfcc1 = mfcc1.T
                    mfcc2 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[1].mean()
                    mfcc2 = mfcc2.T
                    mfcc3 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[2].mean()
                    mfcc3 = mfcc3.T
                    mfcc4 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[3].mean()
                    mfcc4 = mfcc4.T
                    mfcc5 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[4].mean()
                    mfcc5 = mfcc5.T
                    mfcc6 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[5].mean()
                    mfcc6 = mfcc6.T
                    mfcc7 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[6].mean()
                    mfcc7 = mfcc7.T
                    mfcc8 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[7].mean()
                    mfcc8 = mfcc8.T
                    mfcc9 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[8].mean()
                    mfcc9 = mfcc9.T
                    mfcc10 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[9].mean()
                    mfcc10 = mfcc10.T
                    mfcc11 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[10].mean()
                    mfcc11 = mfcc11.T
                    mfcc12 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[11].mean()
                    mfcc12 = mfcc12.T
                    mfcc13 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[12].mean()
                    mfcc13 = mfcc13.T
                    mfcc14 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[13].mean()
                    mfcc14 = mfcc14.T
                    mfcc15 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[14].mean()
                    mfcc15 = mfcc15.T
                    mfcc16 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[15].mean()
                    mfcc16 = mfcc16.T
                    mfcc17 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[16].mean()
                    mfcc17 = mfcc17.T
                    mfcc18 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[17].mean()
                    mfcc18 = mfcc18.T
                    mfcc19 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[18].mean()
                    mfcc19 = mfcc19.T
                    mfcc20 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[19].mean()
                    mfcc20 = mfcc20.T
                    mfcc21 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[20].mean()
                    mfcc21 = mfcc21.T
                    mfcc22 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[21].mean()
                    mfcc22 = mfcc22.T
                    mfcc23 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[22].mean()
                    mfcc23 = mfcc23.T
                    mfcc24 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[23].mean()
                    mfcc24 = mfcc24.T
                    mfcc25 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[24].mean()
                    mfcc25 = mfcc25.T
                    mfcc26 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[25].mean()
                    mfcc26 = mfcc26.T
                    mfcc27 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[26].mean()
                    mfcc27 = mfcc27.T
                    mfcc28 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[27].mean()
                    mfcc28 = mfcc28.T
                    mfcc29 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[28].mean()
                    mfcc29 = mfcc29.T
                    mfcc30 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[29].mean()
                    mfcc30 = mfcc30.T
                    mfcc31 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[30].mean()
                    mfcc31 = mfcc31.T
                    mfcc32 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[31].mean()
                    mfcc32 = mfcc32.T
                    mfcc33 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[32].mean()
                    mfcc33 = mfcc33.T
                    mfcc34 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[33].mean()
                    mfcc34 = mfcc34.T
                    mfcc35 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[34].mean()
                    mfcc35 = mfcc35.T
                    mfcc36 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[35].mean()
                    mfcc36 = mfcc36.T
                    mfcc37 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[36].mean()
                    mfcc37 = mfcc37.T
                    mfcc38 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[37].mean()
                    mfcc38 = mfcc38.T
                    mfcc39 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[38].mean()
                    mfcc39 = mfcc39.T
                    mfcc40 = librosa.feature.mfcc(signal[start:finish], n_mfcc=40)[39].mean()
                    mfcc40 = mfcc40.T   
                    
                    
                    data["chroma_stft1"].append(chroma_stft1.tolist())
                    data["chroma_stft2"].append(chroma_stft2.tolist())
                    data["chroma_stft3"].append(chroma_stft3.tolist())
                    data["chroma_stft4"].append(chroma_stft4.tolist())
                    data["chroma_stft5"].append(chroma_stft5.tolist())
                    data["chroma_stft6"].append(chroma_stft6.tolist())
                    data["chroma_stft7"].append(chroma_stft7.tolist())
                    data["chroma_stft8"].append(chroma_stft8.tolist())
                    data["chroma_stft9"].append(chroma_stft9.tolist())
                    data["chroma_stft10"].append(chroma_stft10.tolist())
                    data["chroma_stft11"].append(chroma_stft11.tolist())
                    data["chroma_stft12"].append(chroma_stft12.tolist())
                    
                    data["chroma_cqt1"].append(chroma_cqt1.tolist())
                    data["chroma_cqt2"].append(chroma_cqt2.tolist())
                    data["chroma_cqt3"].append(chroma_cqt3.tolist())
                    data["chroma_cqt4"].append(chroma_cqt4.tolist())
                    data["chroma_cqt5"].append(chroma_cqt5.tolist())
                    data["chroma_cqt6"].append(chroma_cqt6.tolist())
                    data["chroma_cqt7"].append(chroma_cqt7.tolist())
                    data["chroma_cqt8"].append(chroma_cqt8.tolist())
                    data["chroma_cqt9"].append(chroma_cqt9.tolist())
                    data["chroma_cqt10"].append(chroma_cqt10.tolist())
                    data["chroma_cqt11"].append(chroma_cqt11.tolist())
                    data["chroma_cqt12"].append(chroma_cqt12.tolist())
                    
                    data["chroma_cens1"].append(chroma_cens1.tolist())
                    data["chroma_cens2"].append(chroma_cens2.tolist())
                    data["chroma_cens3"].append(chroma_cens3.tolist())
                    data["chroma_cens4"].append(chroma_cens4.tolist())
                    data["chroma_cens5"].append(chroma_cens5.tolist())
                    data["chroma_cens6"].append(chroma_cens6.tolist())
                    data["chroma_cens7"].append(chroma_cens7.tolist())
                    data["chroma_cens8"].append(chroma_cens8.tolist())
                    data["chroma_cens9"].append(chroma_cens9.tolist())
                    data["chroma_cens10"].append(chroma_cens10.tolist())
                    data["chroma_cens11"].append(chroma_cens11.tolist())
                    data["chroma_cens12"].append(chroma_cens12.tolist())
                    
                    data["rms"].append(rms.tolist())
                    
                    data["spectral_centroid"].append(spectral_centroid.tolist())
                    
                    data["spectral_bandwidth"].append(spectral_bandwidth.tolist())
                    
                    data["spectral_flatness"].append(spectral_flatness.tolist())
                    
                    data["spectral_rolloff"].append(spectral_rolloff.tolist())
                    
                    data["spectral_contrast1"].append(spectral_contrast1.tolist())
                    data["spectral_contrast2"].append(spectral_contrast2.tolist())
                    data["spectral_contrast3"].append(spectral_contrast3.tolist())
                    data["spectral_contrast4"].append(spectral_contrast4.tolist())
                    data["spectral_contrast5"].append(spectral_contrast5.tolist())
                    data["spectral_contrast6"].append(spectral_contrast6.tolist())
                    data["spectral_contrast7"].append(spectral_contrast7.tolist())
                    
                    data["poly_features1"].append(poly_features1.tolist())
                    data["poly_features2"].append(poly_features2.tolist())
                    
                    data["tonnetz1"].append(tonnetz1.tolist())
                    data["tonnetz2"].append(tonnetz2.tolist())
                    data["tonnetz3"].append(tonnetz3.tolist())
                    data["tonnetz4"].append(tonnetz4.tolist())
                    data["tonnetz5"].append(tonnetz5.tolist())
                    data["tonnetz6"].append(tonnetz6.tolist())
                    
                    data["zero_crossing_rate"].append(zero_crossing_rate.tolist())
                    
                    data["mfcc1"].append(mfcc1.tolist())
                    data["mfcc2"].append(mfcc2.tolist())
                    data["mfcc3"].append(mfcc3.tolist())
                    data["mfcc4"].append(mfcc4.tolist())
                    data["mfcc5"].append(mfcc5.tolist())
                    data["mfcc6"].append(mfcc6.tolist())
                    data["mfcc7"].append(mfcc7.tolist())
                    data["mfcc8"].append(mfcc8.tolist())
                    data["mfcc9"].append(mfcc9.tolist())
                    data["mfcc10"].append(mfcc10.tolist())
                    data["mfcc11"].append(mfcc11.tolist())
                    data["mfcc12"].append(mfcc12.tolist())
                    data["mfcc13"].append(mfcc13.tolist())
                    data["mfcc14"].append(mfcc14.tolist())
                    data["mfcc15"].append(mfcc15.tolist())
                    data["mfcc16"].append(mfcc16.tolist())
                    data["mfcc17"].append(mfcc17.tolist())
                    data["mfcc18"].append(mfcc18.tolist())
                    data["mfcc19"].append(mfcc19.tolist())
                    data["mfcc20"].append(mfcc20.tolist())
                    data["mfcc21"].append(mfcc21.tolist())
                    data["mfcc22"].append(mfcc22.tolist())
                    data["mfcc23"].append(mfcc23.tolist())
                    data["mfcc24"].append(mfcc24.tolist())
                    data["mfcc25"].append(mfcc25.tolist())
                    data["mfcc26"].append(mfcc26.tolist())
                    data["mfcc27"].append(mfcc27.tolist())
                    data["mfcc28"].append(mfcc28.tolist())
                    data["mfcc29"].append(mfcc29.tolist())
                    data["mfcc30"].append(mfcc30.tolist())
                    data["mfcc31"].append(mfcc31.tolist())
                    data["mfcc32"].append(mfcc32.tolist())
                    data["mfcc33"].append(mfcc33.tolist())
                    data["mfcc34"].append(mfcc34.tolist())
                    data["mfcc35"].append(mfcc35.tolist())
                    data["mfcc36"].append(mfcc36.tolist())
                    data["mfcc37"].append(mfcc37.tolist())
                    data["mfcc38"].append(mfcc38.tolist())
                    data["mfcc39"].append(mfcc39.tolist())
                    data["mfcc40"].append(mfcc40.tolist())
                    data["label"].append(semantic_label)
                    
                    data["filename"].append(file_path.split('/')[2])
                    print("{}, segment:{}".format(file_path, d+1))

    # save features to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
        
        
if __name__ == "__main__":
    save_new_features(DATASET_PATH, "new_features.json", num_segments=1)
# Out:
# Processing: pop
# genres/pop/pop.00027.wav, segment:1
# genres/pop/pop.00033.wav, segment:1
# genres/pop/pop.00032.wav, segment:1
# genres/pop/pop.00026.wav, segment:1
# genres/pop/pop.00030.wav, segment:1
# genres/pop/pop.00024.wav, segment:1
# genres/pop/pop.00018.wav, segment:1
# genres/pop/pop.00019.wav, segment:1
# genres/pop/pop.00025.wav, segment:1
# genres/pop/pop.00031.wav, segment:1
# genres/pop/pop.00009.wav, segment:1
# genres/pop/pop.00035.wav, segment:1
# genres/pop/pop.00021.wav, segment:1
# genres/pop/pop.00020.wav, segment:1
# genres/pop/pop.00034.wav, segment:1
# genres/pop/pop.00008.wav, segment:1
# genres/pop/pop.00022.wav, segment:1
# genres/pop/pop.00036.wav, segment:1
# genres/pop/pop.00037.wav, segment:1
# genres/pop/pop.00023.wav, segment:1
# genres/pop/pop.00044.wav, segment:1
# genres/pop/pop.00050.wav, segment:1
# genres/pop/pop.00078.wav, segment:1
# genres/pop/pop.00087.wav, segment:1
# genres/pop/pop.00093.wav, segment:1
# ...

# %%
df = pd.read_json("new_features.json")
df = pd.DataFrame(df)
print(df.head())
print('\n dataframe shape:', df.shape)
# Out:
#         filename label  chroma_stft1  chroma_stft2  chroma_stft3  \
# 0  pop.00027.wav   pop      0.299881      0.379244      0.470128
# 1  pop.00033.wav   pop      0.544635      0.350781      0.388006
# 2  pop.00032.wav   pop      0.443481      0.493255      0.373764
# 3  pop.00026.wav   pop      0.463715      0.287497      0.316427
# 4  pop.00030.wav   pop      0.401023      0.533435      0.290821
#
#    chroma_stft4  chroma_stft5  chroma_stft6  chroma_stft7  chroma_stft8  ...  \
# 0      0.325283      0.342244      0.313968      0.442569      0.401032  ...
# 1      0.337791      0.391167      0.430018      0.447838      0.531868  ...
# 2      0.478039      0.476955      0.344388      0.389499      0.403201  ...
# 3      0.245788      0.323225      0.266904      0.250274      0.541873  ...
# 4      0.372626      0.260384      0.372584      0.256875      0.289864  ...
#
#      mfcc31    mfcc32    mfcc33    mfcc34    mfcc35    mfcc36    mfcc37  \
# ...

# %% [markdown]
# ## Pre-Processing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 99 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   filename            1000 non-null   object
#  1   label               1000 non-null   object
#  2   chroma_stft1        1000 non-null   float64
#  3   chroma_stft2        1000 non-null   float64
#  4   chroma_stft3        1000 non-null   float64
#  5   chroma_stft4        1000 non-null   float64
#  6   chroma_stft5        1000 non-null   float64
#  7   chroma_stft6        1000 non-null   float64
#  8   chroma_stft7        1000 non-null   float64
#  9   chroma_stft8        1000 non-null   float64
#  10  chroma_stft9        1000 non-null   float64
#  11  chroma_stft10       1000 non-null   float64
#  12  chroma_stft11       1000 non-null   float64
#  13  chroma_stft12       1000 non-null   float64
#  14  chroma_cqt1         1000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# filename        0
# label           0
# chroma_stft1    0
# chroma_stft2    0
# chroma_stft3    0
#                ..
# mfcc36          0
# mfcc37          0
# mfcc38          0
# mfcc39          0
# mfcc40          0
# Length: 99, dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# We can see that our dataframe is clean as there are no null values or duplicates and since all numerical values are recorded as floats.
